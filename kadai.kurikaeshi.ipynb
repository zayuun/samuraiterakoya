# %%
lists = ["水","金","地","火","木","土","天","海","冥"]

for list in lists:
    print(list)

i = 0

while i < len(lists):
    print(lists[i])

    i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
